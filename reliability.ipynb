# %% [markdown]
# # Reliability
#
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib import rcParams

# %% [markdown]
# ## Code
#
# Define figure dimensions:

# %%
fig_width = 3.25 # single column width
fig_width_2col = 2 * fig_width # double column width
fig_height = (3 / 4) * fig_width

# %% [markdown]
# Define default plot settings:

# %%
rcParams['figure.autolayout'] = True
rcParams['lines.linewidth'] = 1.0
rcParams['font.size'] = 8
rcParams['font.sans-serif'] = 'Arial'
rcParams['mathtext.fontset'] = 'custom'
rcParams['mathtext.rm'] = 'Arial'
rcParams['pdf.fonttype'] = 42
rcParams['ps.fonttype'] = 42

# %% [markdown]
# Do some basic math:

# %%
# Generate the grid
x = np.linspace(1, 5000, 250) # cells in pack
y = np.linspace(0.999, 1, 250) # cell-level reliability
X, Y = np.meshgrid(x, y)

# Compute pack-level reliability
C = Y**X

# %% [markdown]
# Plot:

# %%
plt.figure(figsize=(fig_width, fig_height))
plt.imshow(C, aspect='auto', origin='lower', extent=[-0.1, 5000, 0.999, 1], cmap="viridis_r")
plt.colorbar(label='Pack-level reliability, $R_{pack} = R_{cell}^{n}$')
#plt.xscale('log')
#plt.yscale('log')
plt.xlabel('Number of cells in the pack, $n$')
plt.ylabel('Cell-level reliability, $R_{cell}$')
plt.savefig("figures/reliability.pdf", dpi=300, bbox_inches="tight", format="pdf")

# %% [markdown]
# Pretty striking result if you ask me!
